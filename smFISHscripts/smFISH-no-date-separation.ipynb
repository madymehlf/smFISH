# %%
#scrip to read in the counts as a result of the threshod countimng
#reads in the roi file with the arae
#performs the normalized counting information
#subtracts the apical region from the basal and / over the total number of counts 

import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams['font.size'] = 7
plt.rcParams['font.sans-serif'] = 'Arial'

# %%
#read in the Col4a1 Ecad result files 
Col4a1=pd.read_csv("process-textfiles3/170910 Col4a1 smFISH anti-Ecad anti-Col4 co-staining-processingAll-Summary-2657.csv")
Col4a1.head()
# Out:
#    file_name  selected_threshold  total_dot_number  inside_ROI1  inside_ROI2
# 0          1                   5              8156          279           76
# 1          2                   5              3954          272           80
# 2          3                   5              4251          163           49
# 3          4                   5             10978          369          115
# 4          5                   5              9536          886          288

# %%
#read in the ROi area file 
Col4a1_ROI= pd.read_csv("process-textfiles3/170902 Col4a1 smFISH-ROIarea.csv")
Col4a1_ROI.head()
# Out:
#                     file_name   AreaROI1  AreaROI2
# 0  20170902 Col4a1 smFISH 001   886.9636  468.1528
# 1  20170902 Col4a1 smFISH 002   902.8959  512.2805
# 2  20170902 Col4a1 smFISH 003   866.9114  497.6034
# 3  20170902 Col4a1 smFISH 004  1059.0971  542.1817
# 4  20170902 Col4a1 smFISH 005   852.3309  419.8730

# %%
#Col4a1
Col4a1_apical=Col4a1.inside_ROI1-Col4a1.inside_ROI2
Col4a1_basal=Col4a1.inside_ROI2
ROI_apical_Col4a1= Col4a1_ROI.AreaROI1-Col4a1.inside_ROI2
ROI_basal_Col4a1= Col4a1_ROI.AreaROI2

Col4a1_apical_norm= (Col4a1_apical)/(ROI_apical_Col4a1)
Col4a1_basal_norm= (Col4a1_basal)/(ROI_basal_Col4a1)
Col4a1_total_norm= (Col4a1_apical_norm)+(Col4a1_basal_norm)

# Col4a1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Group'])
# Col4a1_df.Apical= Col4a1_apical_norm
# Col4a1_df.Basal=Col4a1_basal_norm
# Col4a1_df.Total=Col4a1_total_norm
# Col4a1_df['Score']= ((Col4a1_df.Apical.sub)-(Col4a1_df.Basal)/(Col4a1_df.Total))

# %%
Col4a1['Col4a1_apical_norm']= Col4a1_apical_norm
Col4a1['Col4a1_basal_norm']= Col4a1_basal_norm
Col4a1['Col4a1_total_norm']= Col4a1_total_norm
Col4a1.head()
# Out:
#    file_name  selected_threshold  total_dot_number  inside_ROI1  inside_ROI2  \
# 0          1                   5              8156          279           76
# 1          2                   5              3954          272           80
# 2          3                   5              4251          163           49
# 3          4                   5             10978          369          115
# 4          5                   5              9536          886          288
#
#    Col4a1_apical_norm  Col4a1_basal_norm  Col4a1_total_norm
# 0            0.250319           0.162340           0.412660
# 1            0.233322           0.156164           0.389487
# 2            0.139379           0.098472           0.237851
# 3            0.269040           0.212106           0.481146
# 4            1.059662           0.685922           1.745584

# %%
Col4a1['Score']= (Col4a1_apical_norm)-(Col4a1_basal_norm)/(Col4a1_total_norm)
Col4a1.head()
# Out:
#    file_name  selected_threshold  total_dot_number  inside_ROI1  inside_ROI2  \
# 0          1                   5              8156          279           76
# 1          2                   5              3954          272           80
# 2          3                   5              4251          163           49
# 3          4                   5             10978          369          115
# 4          5                   5              9536          886          288
#
#    Col4a1_apical_norm  Col4a1_basal_norm  Col4a1_total_norm     Score
# 0            0.250319           0.162340           0.412660 -0.143080
# 1            0.233322           0.156164           0.389487 -0.167627
# 2            0.139379           0.098472           0.237851 -0.274627
# 3            0.269040           0.212106           0.481146 -0.171795
# 4            1.059662           0.685922           1.745584  0.666715

# %%
#Col4a2
Col4a2=pd.read_csv("")
Col4a1_ROI=pd.read_csv("")
Col4a2_apical=Col4a2.inside_ROI1-Col4a2.inside_ROI2
Col4a2_basal=Col4a2.inside_ROI2
ROI_apical_Col4a2= Col4a2_ROI.AreaROI1-Col4a2.inside_ROI2
ROI_basal_Col4a2= Col4a2_ROI.AreaROI2
 
Col4a2_apical_norm= (Col4a2_apical)/(ROI_apical_Col4a2)
Col4a2_basal_norm= (Col4a2_basal)/(ROI_basal_Col4a2)
Col4a2_total_norm= (Col4a2_apical_norm)+(Col4a2_basal_norm)
 
Col4a2_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
Col4a2_df.Apical= Col4a2_apical_norm
Col4a2_df.Basal=Col4a2_basal_norm
Col4a2_df.Total=Col4a2_total_norm
Col4a2_df.Score= ((Col4a2_df.Apical)-(Col4a2_df.Basal))/(Col4a2_total_norm)
Col4a2_df.Group= "Col4a2"
Col4a2_df.head()

# %%
#lamb1
#Col4a2
lamb1=pd.read_csv("")
lamb1_ROI=pd.read_csv("")
lamb1_apical=lamb1.inside_ROI1-lamb1.inside_ROI2
lamb1_basal=lamb1.inside_ROI2
ROI_apical_lamb1= lamb1_ROI.AreaROI1-lamb1.inside_ROI2
ROI_basal_lamb1= lamb1_ROI.AreaROI2
 
lamb1_apical_norm= (lamb1_apical)/(ROI_apical_lamb1)
lamb1_basal_norm= (lamb1_basal)/(ROI_basal_lamb1)
lamb1_total_norm= (lamb1_apical_norm)+(lamb1_basal_norm)
 
lamb1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
lamb1_df.Apical= lamb1_apical_norm
lamb1_df.Basal=lamb1_basal_norm
lamb1_df.Total=lamb1_total_norm
lamb1_df.Score= ((lamb1_df.Apical)-(lamb1_df.Basal))/(lamb1_total_norm)
lamb1_df.Group= "lamb1"
lamb1_df.head()

# %%
#lamc1
lamc1=pd.read_csv("")
lamc1_ROI=pd.read_csv("")
lamc1_apical=lamc1.inside_ROI1-lamc1.inside_ROI2
lamc1_basal=lamc1.inside_ROI2
ROI_apical_lamc1= lamc1_ROI.AreaROI1-lamc1.inside_ROI2
ROI_basal_lamc1= lamc1_ROI.AreaROI2
 
lamc1_apical_norm= (lamc1_apical)/(ROI_apical_lamc1)
lamc1_basal_norm= (lamc1_basal)/(ROI_basal_lamc1)
lamc1_total_norm= (lamc1_apical_norm)+(lamc1_basal_norm)
 
lamc1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
lamc1_df.Apical= lamc1_apical_norm
lamc1_df.Basal=lamc1_basal_norm
lamc1_df.Total=lamc1_total_norm
lamc1_df.Score= ((lamc1_df.Apical)-(lamc1_df.Basal))/(lamc1_total_norm)
lamc1_df.Group= "lamc1"
lamc1_df.head()

# %%
#Emg1
emg1=pd.read_csv("")
emg1_ROI=pd.read_csv("")
emg1_apical=emg1.inside_ROI1-emg1.inside_ROI2
emg1_basal=emg1.inside_ROI2
ROI_apical_emg1= emg1_ROI.AreaROI1-emg1.inside_ROI2
ROI_basal_emg1= emg1_ROI.AreaROI2
 
emg1_apical_norm= (emg1_apical)/(ROI_apical_emg1)
emg1_basal_norm= (emg1_basal)/(ROI_basal_emg1)
emg1_total_norm= (emg1_apical_norm)+(emg1_basal_norm)
 
emg1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
emg1_df.Apical= emg1_apical_norm
emg1_df.Basal=emg1_basal_norm
emg1_df.Total=emg1_total_norm
emg1_df.Score= ((emg1_df.Apical)-(emg1_df.Basal))/(emg1_total_norm)
emg1_df.Group= "emg1"
emg1_df.head()

# %%
#Net1
net1=pd.read_csv("")
net1_ROI=pd.read_csv("")
net1_apical=net1.inside_ROI1-net1.inside_ROI2
net1_basal=net1.inside_ROI2
ROI_apical_net1= net1_ROI.AreaROI1-net1.inside_ROI2
ROI_basal_net1= net1_ROI.AreaROI2
 
net1_apical_norm= (net1_apical)/(ROI_apical_net1)
net1_basal_norm= (net1_basal)/(ROI_basal_net1)
net1_total_norm= (net1_apical_norm)+(net1_basal_norm)
 
net1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
net1_df.Apical= net1_apical_norm
net1_df.Basal=net1_basal_norm
net1_df.Total=net1_total_norm
net1_df.Score= ((net1_df.Apical)-(net1_df.Basal))/(net1_total_norm)
net1_df.Group= "net1"
net1_df.head()

# %%
#Fn1
fn1=pd.read_csv("")
fn1_ROI=pd.read_csv("")
fn1_apical=fn1.inside_ROI1-fn1.inside_ROI2
fn1_basal=fn1.inside_ROI2
ROI_apical_fn1= fn1_ROI.AreaROI1-fn1.inside_ROI2
ROI_basal_fn1= fn1_ROI.AreaROI2
 
fn1_apical_norm= (fn1_apical)/(ROI_apical_fn1)
fn1_basal_norm= (fn1_basal)/(ROI_basal_fn1)
fn1_total_norm= (fn1_apical_norm)+(fn1_basal_norm)
 
fn1_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
fn1_df.Apical= fn1_apical_norm
fn1_df.Basal=fn1_basal_norm
fn1_df.Total=fn1_total_norm
fn1_df.Score= ((fn1_df.Apical)-(fn1_df.Basal))/(fn1_total_norm)
fn1_df.Group= "fn1"
fn1_df.head()

# %%
#Hspg2
hspg2=pd.read_csv("")
hspg2_ROI=pd.read_csv("")
hspg2_apical=hspg2.inside_ROI1-hspg2.inside_ROI2
hspg2_basal=hspg2.inside_ROI2
ROI_apical_hspg2= hspg2_ROI.AreaROI1-hspg2.inside_ROI2
ROI_basal_hspg2= hspg2_ROI.AreaROI2
 
hspg2_apical_norm= (hspg2_apical)/(ROI_apical_hspg2)
hspg2_basal_norm= (hspg2_basal)/(ROI_basal_hspg2)
hspg2_total_norm= (hspg2_apical_norm)+(hspg2_basal_norm)
 
hspg2_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
hspg2_df.Apical= hspg2_apical_norm
hspg2_df.Basal=hspg2_basal_norm
hspg2_df.Total=hspg2_total_norm
hspg2_df.Score= ((hspg2_df.Apical)-(hspg2_df.Basal))/(hspg2_total_norm)
hspg2_df.Group= "hspg2"
hspg2_df.head()

# %%
#GADPH
GADPH=pd.read_csv("")
GADPH_ROI=pd.read_csv("")
GADPH_apical=GADPH.inside_ROI1-GADPH.inside_ROI2
GADPH_basal=GADPH.inside_ROI2
ROI_apical_GADPH= GADPH_ROI.AreaROI1-GADPH.inside_ROI2
ROI_basal_GADPH= GADPH_ROI.AreaROI2
 
GADPH_apical_norm= (GADPH_apical)/(ROI_apical_GADPH)
GADPH_basal_norm= (GADPH_basal)/(ROI_basal_GADPH)
GADPH_total_norm= (GADPH_apical_norm)+(GADPH_basal_norm)
 
GADPH_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
GADPH_df.Apical= GADPH_apical_norm
GADPH_df.Basal=GADPH_basal_norm
GADPH_df.Total=GADPH_total_norm
GADPH_df.Score= ((GADPH_df.Apical)-(GADPH_df.Basal))/(GADPH_total_norm)
GADPH_df.Group= "GADPH"
GADPH_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-4b479fc653f3> in <module>()
# ----> 1 GADPH=pd.read_csv("")
#       2 GADPH_ROI=pd.read_csv("")
#       3 GADPH_apical=GADPH.inside_ROI1-GADPH.inside_ROI2
#       4 GADPH_basal=GADPH.inside_ROI2
#       5 ROI_apical_GADPH= GADPH_ROI.AreaROI1-GADPH.inside_ROI2
#
# ...

# %%
#SOX1O
Sox10=pd.read_csv("")
Sox10_ROI=pd.read_csv("")
Sox10_apical=Sox10.inside_ROI1-Sox10.inside_ROI2
Sox10_basal=Sox10.inside_ROI2
ROI_apical_Sox10= Sox10_ROI.AreaROI1-Sox10.inside_ROI2
ROI_basal_Sox10= Sox10_ROI.AreaROI2
 
Sox10_apical_norm= (Sox10_apical)/(ROI_apical_Sox10)
Sox10_basal_norm= (Sox10_basal)/(ROI_basal_Sox10)
Sox10_total_norm= (Sox10_apical_norm)+(Sox10_basal_norm)
 
Sox10_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
Sox10_df.Apical= Sox10_apical_norm
Sox10_df.Basal=Sox10_basal_norm
Sox10_df.Total=Sox10_total_norm
Sox10_df.Score= ((Sox10_df.Apical)-(Sox10_df.Basal))/(Sox10_total_norm)
Sox10_df.Group= "Sox10"
Sox10_df.head()

# %%
#Sox9
Sox9=pd.read_csv("")
Sox9_ROI=pd.read_csv("")
Sox9_apical=Sox9.inside_ROI1-Sox9.inside_ROI2
Sox9_basal=Sox9.inside_ROI2
ROI_apical_Sox9= Sox9_ROI.AreaROI1-Sox9.inside_ROI2
ROI_basal_Sox9= Sox9_ROI.AreaROI2
 
Sox9_apical_norm= (Sox9_apical)/(ROI_apical_Sox9)
Sox9_basal_norm= (Sox9_basal)/(ROI_basal_Sox9)
Sox9_total_norm= (Sox9_apical_norm)+(Sox9_basal_norm)
 
Sox9_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
Sox9_df.Apical= Sox9_apical_norm
Sox9_df.Basal=Sox9_basal_norm
Sox9_df.Total=Sox9_total_norm
Sox9_df.Score= ((Sox9_df.Apical)-(Sox9_df.Basal))/(Sox9_total_norm)
Sox9_df.Group= "Sox9"
Sox9_df.head()

# %%
#Pax9 
Pax9=pd.read_csv("")
Pax9_ROI=pd.read_csv("")
Pax9_apical=Pax9.inside_ROI1-Pax9.inside_ROI2
Pax9_basal=Pax9.inside_ROI2
ROI_apical_Pax9= Pax9_ROI.AreaROI1-Pax9.inside_ROI2
ROI_basal_Pax9= Pax9_ROI.AreaROI2
 
Pax9_apical_norm= (Pax9_apical)/(ROI_apical_Pax9)
Pax9_basal_norm= (Pax9_basal)/(ROI_basal_Pax9)
Pax9_total_norm= (Pax9_apical_norm)+(Pax9_basal_norm)
 
Pax9_df=pd.DataFrame(columns=['Apical', 'Basal', 'Total', 'Polarity-Score', 'Group'])
Pax9_df.Apical= Pax9_apical_norm
Pax9_df.Basal=Pax9_basal_norm
Pax9_df.Total=Pax9_total_norm
Pax9_df.Score= ((Pax9_df.Apical)-(Pax9_df.Basal))/(Pax9_total_norm)
Pax9_df.Group= "Pax9"
Pax9_df.head()

# %%
#swarmplot
swarm= sns.swarmplot(x="Group", y="Polarity", data=)
